# %% [markdown]
# # Basic EDA and Feature extraction on Dataset

# %% [markdown]
# ### import libraries

# %%
import os
import sys
import subprocess
import numpy as np
import seaborn as sns
import json
import pandas as pd
import shutil
import librosa.display
import matplotlib
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# ### import data

# %%
train_csv = pd.read_csv("/home/abhijeet/Desktop/extracted/train.csv")

# %%
train_csv.head()
# Out:
#                              id  \
# 0  iOx0zPyPiMZjCWXuf3RGu8HKq8k1
# 1  gFmySpqfQ7YrYqMrmrMPO7AzmBm1
# 2  padXEGczMRRKmLRVc68rEKI142B3
# 3  ymX9t6DWDHZTs28MODDSxDaOj4n2
# 4  loK2K444HrZUD8Plzr6q3i8y4Xg1
#
#                                                 path file_status  \
# 0  /home/abhijeet/Desktop/extracted/20210630/iOx0...           Y
# 1  /home/abhijeet/Desktop/extracted/20210630/gFmy...           Y
# 2  /home/abhijeet/Desktop/extracted/20210630/padX...           Y
# 3  /home/abhijeet/Desktop/extracted/20210630/ymX9...           Y
# 4  /home/abhijeet/Desktop/extracted/20210630/loK2...           Y
#
#     covid_status      date    str_date    status
# 0  positive_mild  20210630  2021-06-30  positive
# 1  positive_mild  20210628  2021-06-28  positive
# 2  positive_mild  20210628  2021-06-28  positive
# 3  positive_mild  20210628  2021-06-28  positive
# 4  positive_mild  20210628  2021-06-28  positive

# %%
train_csv['status'].unique()
# Out:
# array(['positive', 'negative'], dtype=object)

# %%
train_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2312 entries, 0 to 2311
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            2312 non-null   object
#  1   path          2312 non-null   object
#  2   file_status   2312 non-null   object
#  3   covid_status  2312 non-null   object
#  4   date          2312 non-null   int64
#  5   str_date      2312 non-null   object
#  6   status        2312 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 126.6+ KB

# %%
train_csv['path'].loc[1][-44:-16]
# Out:
# 'gFmySpqfQ7YrYqMrmrMPO7AzmBm1'

# %%
# os.path.isfile("./home" )
os.chdir("/home/abhijeet/Desktop/extracted/png/")

# %%
header = 'filename chroma_stft rmse spectral_centroid spectral_bandwidth rolloff zero_crossing_rate'
for i in range(1, ):
    header += f' mfcc{i}'
header += ' label'
header = header.split()

file = open('/home/abhijeet/Desktop/train.csv', 'w')
with file:
    writer = csv.writer(file)
    writer.writerow(header)
for i in range(2312):
    try :
        filename = train_csv['path'][i]
        y,sr = librosa.load(filename, sr =22050)
        chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
        rmse = librosa.feature.rms(y=y)
        spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
        spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
        rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
        zcr = librosa.feature.zero_crossing_rate(y)
        mfcc = librosa.feature.mfcc(y=y, sr=sr)
        to_append = f'{filename[:-3].replace(".", "")} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
        for e in mfcc:
            to_append += f' {np.mean(e)}'
        
        file = open('/home/abhijeet/Desktop/train.csv', 'a')
        with file:
            writer = csv.writer(file)
            writer.writerow(to_append.split())
    except :
        continue
# y=[]; chroma_stft =np.ndarray(0);rmse =[]; spec_cent =[];spec_bw =[];
# rollof =[]; zcr =[];mfcc_n = [];sr=[]
# for i in range(0, 2312):
#         filename = train_csv['path'][i]
#         s,sr= librosa.load(filename, mono=True, duration=5)
#         y+=[s]
#         chroma_stft.append(np.array(librosa.feature.chroma_stft(y=y, sr=sr)))
#         rmse += [librosa.feature.rms(y=y)]
#         spec_cent += [librosa.feature.spectral_centroid(y=y, sr=sr)]
#         spec_bw += [librosa.feature.spectral_bandwidth(y=y, sr=sr)]
#         rolloff +=[ librosa.feature.spectral_rolloff(y=y, sr=sr)]
#         zcr += [librosa.feature.zero_crossing_rate(y)]
#         mfcc = librosa.feature.mfcc(y=y, sr=sr)
#         for e in mfcc :
#             mfcc_n += [np.mean(e)]
#         print('..')
# Out:
# /home/abhijeet/anaconda3/envs/mini/lib/python3.9/site-packages/librosa/util/decorators.py:88: UserWarning: Trying to estimate tuning from empty frequency set.
#   return f(*args, **kwargs)
# /home/abhijeet/anaconda3/envs/mini/lib/python3.9/site-packages/librosa/util/decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1882
#   return f(*args, **kwargs)

# %%
data = pd.read_csv('/home/abhijeet/Desktop/train1.csv')
data.head()
# Out:
#                                             filename  chroma_stft      rmse  \
# 0  /home/abhijeet/Desktop/extracted/20210630/iOx0...     0.571208  0.017260
# 1  /home/abhijeet/Desktop/extracted/20210630/gFmy...     0.485491  0.055333
# 2  /home/abhijeet/Desktop/extracted/20210630/padX...     0.575894  0.031052
# 3  /home/abhijeet/Desktop/extracted/20210630/ymX9...     0.525386  0.044825
# 4  /home/abhijeet/Desktop/extracted/20210630/loK2...     0.571209  0.041385
#
#    spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 0        1816.135002         1825.064974  3654.356836            0.329156
# 1        1803.227275         1514.007823  3375.087099            0.179753
# 2        2309.826271         1891.974883  4314.941977            0.260138
# 3        2033.952673         1637.164773  3715.567276            0.289644
# 4        2294.375713         1698.955349  4093.764134            0.247430
#
#         mfcc1      mfcc2      mfcc3  ...     mfcc12     mfcc13    mfcc14  \
# 0 -483.492584  58.155170  -2.718263  ...  -6.044026 -10.262712 -7.170579
# 1 -369.920105  77.721184 -43.531815  ... -10.802448   0.471163 -0.685309
# 2 -482.871155  53.619247 -17.301470  ...  -6.780571  -3.648542 -5.524356
# 3 -410.733032  44.620586 -28.204554  ...  -4.293538   1.291801 -6.491752
# 4 -440.584259  74.668716 -45.951244  ...  -5.298672  -0.054777 -3.501513
#
#       mfcc15    mfcc16    mfcc17    mfcc18    mfcc19    mfcc20  label
# 0  -3.980177 -5.199104 -4.095163 -1.385846 -4.265814 -3.388773    NaN
# 1 -12.754487 -6.946540 -6.162850 -7.796247 -6.396797 -4.871747    NaN
# 2  -4.748296 -5.530713 -5.959706 -5.688097 -4.610028 -3.440410    NaN
# 3  -4.877913  0.042963 -6.877393 -1.274811  2.375689 -2.818016    NaN
# 4  -3.407240 -6.497522 -4.536685 -4.217173 -7.038527 -3.456792    NaN
#
# [5 rows x 28 columns]

# %%
# data['filename'][0][42:70]

data['id']=data.filename.apply(lambda x: x[42:70])
data.head()
# Out:
#                                             filename  chroma_stft      rmse  \
# 0  /home/abhijeet/Desktop/extracted/20210630/iOx0...     0.571208  0.017260
# 1  /home/abhijeet/Desktop/extracted/20210630/gFmy...     0.485491  0.055333
# 2  /home/abhijeet/Desktop/extracted/20210630/padX...     0.575894  0.031052
# 3  /home/abhijeet/Desktop/extracted/20210630/ymX9...     0.525386  0.044825
# 4  /home/abhijeet/Desktop/extracted/20210630/loK2...     0.571209  0.041385
#
#    spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 0        1816.135002         1825.064974  3654.356836            0.329156
# 1        1803.227275         1514.007823  3375.087099            0.179753
# 2        2309.826271         1891.974883  4314.941977            0.260138
# 3        2033.952673         1637.164773  3715.567276            0.289644
# 4        2294.375713         1698.955349  4093.764134            0.247430
#
#         mfcc1      mfcc2      mfcc3  ...     mfcc13    mfcc14     mfcc15  \
# 0 -483.492584  58.155170  -2.718263  ... -10.262712 -7.170579  -3.980177
# 1 -369.920105  77.721184 -43.531815  ...   0.471163 -0.685309 -12.754487
# 2 -482.871155  53.619247 -17.301470  ...  -3.648542 -5.524356  -4.748296
# 3 -410.733032  44.620586 -28.204554  ...   1.291801 -6.491752  -4.877913
# 4 -440.584259  74.668716 -45.951244  ...  -0.054777 -3.501513  -3.407240
#
#      mfcc16    mfcc17    mfcc18    mfcc19    mfcc20  label  \
# 0 -5.199104 -4.095163 -1.385846 -4.265814 -3.388773    NaN
# 1 -6.946540 -6.162850 -7.796247 -6.396797 -4.871747    NaN
# 2 -5.530713 -5.959706 -5.688097 -4.610028 -3.440410    NaN
# 3  0.042963 -6.877393 -1.274811  2.375689 -2.818016    NaN
# 4 -6.497522 -4.536685 -4.217173 -7.038527 -3.456792    NaN
#
#                              id
# 0  iOx0zPyPiMZjCWXuf3RGu8HKq8k1
# 1  gFmySpqfQ7YrYqMrmrMPO7AzmBm1
# 2  padXEGczMRRKmLRVc68rEKI142B3
# 3  ymX9t6DWDHZTs28MODDSxDaOj4n2
# 4  loK2K444HrZUD8Plzr6q3i8y4Xg1
#
# [5 rows x 29 columns]

# %%
# cmap = plt.get_cmap('inferno')
# tot_rows = train_csv.shape[0]
# for i in range(tot_rows):
# #     source = train_csv['file_properties'][i]
#     filename = train_csv['path'][i]
#     y,sr = librosa.load(filename, sr = 22050)
#     plt.specgram(y, NFFT=2048, Fs=2, Fc=0, noverlap=128, cmap=cmap, sides='default', mode='default', scale='dB');
#     plt.axis('off');
#     plt.savefig("/home/abhijeet/Desktop/extracted/png/" + filename[-53:-45] + "/"+ filename[-44:-16]+  "-mfcc.png")
#     plt.clf()

# %%
tdf = pd.merge(train_csv ,data ,on ='id')
tdf.head()
# Out:
#                              id  \
# 0  iOx0zPyPiMZjCWXuf3RGu8HKq8k1
# 1  gFmySpqfQ7YrYqMrmrMPO7AzmBm1
# 2  padXEGczMRRKmLRVc68rEKI142B3
# 3  ymX9t6DWDHZTs28MODDSxDaOj4n2
# 4  loK2K444HrZUD8Plzr6q3i8y4Xg1
#
#                                                 path file_status  \
# 0  /home/abhijeet/Desktop/extracted/20210630/iOx0...           Y
# 1  /home/abhijeet/Desktop/extracted/20210630/gFmy...           Y
# 2  /home/abhijeet/Desktop/extracted/20210630/padX...           Y
# 3  /home/abhijeet/Desktop/extracted/20210630/ymX9...           Y
# 4  /home/abhijeet/Desktop/extracted/20210630/loK2...           Y
#
#     covid_status      date    str_date    status  \
# 0  positive_mild  20210630  2021-06-30  positive
# 1  positive_mild  20210628  2021-06-28  positive
# 2  positive_mild  20210628  2021-06-28  positive
# 3  positive_mild  20210628  2021-06-28  positive
# 4  positive_mild  20210628  2021-06-28  positive
#
#                                             filename  chroma_stft      rmse  \
# 0  /home/abhijeet/Desktop/extracted/20210630/iOx0...     0.571208  0.017260
# 1  /home/abhijeet/Desktop/extracted/20210630/gFmy...     0.485491  0.055333
# 2  /home/abhijeet/Desktop/extracted/20210630/padX...     0.575894  0.031052
# 3  /home/abhijeet/Desktop/extracted/20210630/ymX9...     0.525386  0.044825
# 4  /home/abhijeet/Desktop/extracted/20210630/loK2...     0.571209  0.041385
#
#    ...     mfcc12     mfcc13    mfcc14     mfcc15    mfcc16    mfcc17  \
# 0  ...  -6.044026 -10.262712 -7.170579  -3.980177 -5.199104 -4.095163
# 1  ... -10.802448   0.471163 -0.685309 -12.754487 -6.946540 -6.162850
# 2  ...  -6.780571  -3.648542 -5.524356  -4.748296 -5.530713 -5.959706
# 3  ...  -4.293538   1.291801 -6.491752  -4.877913  0.042963 -6.877393
# 4  ...  -5.298672  -0.054777 -3.501513  -3.407240 -6.497522 -4.536685
#
#      mfcc18    mfcc19    mfcc20  label
# 0 -1.385846 -4.265814 -3.388773    NaN
# 1 -7.796247 -6.396797 -4.871747    NaN
# 2 -5.688097 -4.610028 -3.440410    NaN
# 3 -1.274811  2.375689 -2.818016    NaN
# 4 -4.217173 -7.038527 -3.456792    NaN
#
# [5 rows x 35 columns]

# %%
tdf = tdf.drop(['file_status','covid_status','str_date','filename','label'],axis =1)

# %%
tdf.to_csv("/home/abhijeet/Desktop/extracted/train2.csv",index= False)

# %%
df = pd.read_csv("/home/abhijeet/Desktop/extracted/train2.csv")

# %%
df.head()
# Out:
#                              id  \
# 0  iOx0zPyPiMZjCWXuf3RGu8HKq8k1
# 1  gFmySpqfQ7YrYqMrmrMPO7AzmBm1
# 2  padXEGczMRRKmLRVc68rEKI142B3
# 3  ymX9t6DWDHZTs28MODDSxDaOj4n2
# 4  loK2K444HrZUD8Plzr6q3i8y4Xg1
#
#                                                 path      date    status  \
# 0  /home/abhijeet/Desktop/extracted/20210630/iOx0...  20210630  positive
# 1  /home/abhijeet/Desktop/extracted/20210630/gFmy...  20210628  positive
# 2  /home/abhijeet/Desktop/extracted/20210630/padX...  20210628  positive
# 3  /home/abhijeet/Desktop/extracted/20210630/ymX9...  20210628  positive
# 4  /home/abhijeet/Desktop/extracted/20210630/loK2...  20210628  positive
#
#    chroma_stft      rmse  spectral_centroid  spectral_bandwidth      rolloff  \
# 0     0.571208  0.017260        1816.135002         1825.064974  3654.356836
# 1     0.485491  0.055333        1803.227275         1514.007823  3375.087099
# 2     0.575894  0.031052        2309.826271         1891.974883  4314.941977
# 3     0.525386  0.044825        2033.952673         1637.164773  3715.567276
# 4     0.571209  0.041385        2294.375713         1698.955349  4093.764134
#
#    zero_crossing_rate  ...    mfcc11     mfcc12     mfcc13    mfcc14  \
# 0            0.329156  ... -5.987736  -6.044026 -10.262712 -7.170579
# 1            0.179753  ...  0.848334 -10.802448   0.471163 -0.685309
# 2            0.260138  ... -4.543019  -6.780571  -3.648542 -5.524356
# 3            0.289644  ... -1.146640  -4.293538   1.291801 -6.491752
# 4            0.247430  ... -4.286937  -5.298672  -0.054777 -3.501513
#
#       mfcc15    mfcc16    mfcc17    mfcc18    mfcc19    mfcc20
# 0  -3.980177 -5.199104 -4.095163 -1.385846 -4.265814 -3.388773
# 1 -12.754487 -6.946540 -6.162850 -7.796247 -6.396797 -4.871747
# 2  -4.748296 -5.530713 -5.959706 -5.688097 -4.610028 -3.440410
# 3  -4.877913  0.042963 -6.877393 -1.274811  2.375689 -2.818016
# 4  -3.407240 -6.497522 -4.536685 -4.217173 -7.038527 -3.456792
#
# [5 rows x 30 columns]
